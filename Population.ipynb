# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
population=pd.read_csv("D:\\Prodigy Info-tech\\Task -1\\Population.csv")

# %%
population
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                  Indicator Name     Indicator Code       1960  \
# 0    Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.858849
# 1    Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.387880
# 2    Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 3    Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.179683
# ...

# %%
population.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                Indicator Name     Indicator Code       1960  \
# 0  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.858849
# 1  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.387880
# 2  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 3  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.179683
# 4  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  49.843790
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0  50.850191  50.845065  50.836016  50.826773  50.823381  ...  52.442652
# 1  50.388814  50.391276  50.395656  50.400512  50.405510  ...  50.577372
# ...

# %%
population.tail()
# Out:
#      Country Name Country Code                              Indicator Name  \
# 261        Kosovo          XKX  Population, female (% of total population)
# 262   Yemen, Rep.          YEM  Population, female (% of total population)
# 263  South Africa          ZAF  Population, female (% of total population)
# 264        Zambia          ZMB  Population, female (% of total population)
# 265      Zimbabwe          ZWE  Population, female (% of total population)
#
#         Indicator Code       1960       1961       1962       1963       1964  \
# 261  SP.POP.TOTL.FE.ZS  49.257789  49.245768  49.236004  49.227738  49.219362
# 262  SP.POP.TOTL.FE.ZS  50.090168  50.133512  50.186116  50.251672  50.307585
# 263  SP.POP.TOTL.FE.ZS  48.533692  48.640410  48.745690  48.851474  48.954311
# 264  SP.POP.TOTL.FE.ZS  50.488903  50.508674  50.527844  50.546442  50.566366
# 265  SP.POP.TOTL.FE.ZS  50.503874  50.528305  50.550845  50.571874  50.592112
#
# ...

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            265 non-null    float64
#  5   1961            265 non-null    float64
#  6   1962            265 non-null    float64
#  7   1963            265 non-null    float64
#  8   1964            265 non-null    float64
#  9   1965            265 non-null    float64
#  10  1966            265 non-null    float64
#  11  1967            265 non-null    float64
#  12  1968            265 non-null    float64
#  13  1969            265 non-null    float64
#  14  1970            265 non-null    float64
#  15  1971            265 non-null    float64
#  16  1972            265 non-null    float64
# ...

# %%
population.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  265.000000  265.000000  265.000000  265.000000  265.000000  265.000000
# mean    50.262973   50.237735   50.217159   50.197794   50.182942   50.172804
# std      2.284638    2.266150    2.222031    2.172224    2.126511    2.086509
# min     36.359668   35.808963   36.181818   36.918045   37.691466   38.059345
# 25%     49.454622   49.434260   49.444247   49.424209   49.402764   49.454264
# 50%     50.198854   50.181338   50.165278   50.145059   50.140182   50.151537
# 75%     51.375576   51.384229   51.328503   51.271530   51.254126   51.225036
# max     55.943852   55.792455   55.650640   55.517600   55.394712   55.284695
#
#              1966        1967        1968        1969  ...        2013  \
# count  265.000000  265.000000  265.000000  265.000000  ...  265.000000
# mean    50.166423   50.160010   50.147600   50.132939  ...   49.970823
# ...

# %%
population.shape
# Out:
# (266, 67)

# %%
population.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              1
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
#delete unuseful columns
population.drop(columns=['Country Code', 'Indicator Name'],inplace = True)

# %%
population.head()
# Out:
#                   Country Name     Indicator Code       1960       1961  \
# 0                        Aruba  SP.POP.TOTL.FE.ZS  50.858849  50.850191
# 1  Africa Eastern and Southern  SP.POP.TOTL.FE.ZS  50.387880  50.388814
# 2                  Afghanistan  SP.POP.TOTL.FE.ZS  48.083054  48.165001
# 3   Africa Western and Central  SP.POP.TOTL.FE.ZS  50.179683  50.194408
# 4                       Angola  SP.POP.TOTL.FE.ZS  49.843790  49.700946
#
#         1962       1963       1964       1965       1966       1967  ...  \
# 0  50.845065  50.836016  50.826773  50.823381  50.825589  50.826585  ...
# 1  50.391276  50.395656  50.400512  50.405510  50.410713  50.413312  ...
# 2  48.242372  48.315893  48.385273  48.450285  48.511803  48.570464  ...
# 3  50.203157  50.203679  50.204549  50.204173  50.200936  50.203165  ...
# 4  49.673797  49.634980  49.576791  49.488336  49.364408  49.213634  ...
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %%
#data for total population
total_population=population[population['Indicator Code']== 'SP.POP.TOTL.FE.ZS']

# %%
total_population
# Out:
#                     Country Name     Indicator Code       1960       1961  \
# 0                          Aruba  SP.POP.TOTL.FE.ZS  50.858849  50.850191
# 1    Africa Eastern and Southern  SP.POP.TOTL.FE.ZS  50.387880  50.388814
# 2                    Afghanistan  SP.POP.TOTL.FE.ZS  48.083054  48.165001
# 3     Africa Western and Central  SP.POP.TOTL.FE.ZS  50.179683  50.194408
# 4                         Angola  SP.POP.TOTL.FE.ZS  49.843790  49.700946
# ..                           ...                ...        ...        ...
# 261                       Kosovo  SP.POP.TOTL.FE.ZS  49.257789  49.245768
# 262                  Yemen, Rep.  SP.POP.TOTL.FE.ZS  50.090168  50.133512
# 263                 South Africa  SP.POP.TOTL.FE.ZS  48.533692  48.640410
# 264                       Zambia  SP.POP.TOTL.FE.ZS  50.488903  50.508674
# 265                     Zimbabwe  SP.POP.TOTL.FE.ZS  50.503874  50.528305
#
#           1962       1963       1964       1965       1966       1967  ...  \
# ...

# %%
#sort data based on total population for 2022
total_population_sort=total_population.sort_values(by='2022',ascending=False)

# %%
total_population_sort
# Out:
#              Country Name     Indicator Code       1960       1961       1962  \
# 10                Armenia  SP.POP.TOTL.FE.ZS  51.441327  51.396935  51.358769
# 248               Ukraine  SP.POP.TOTL.FE.ZS  55.483038  55.382402  55.288117
# 25                Belarus  SP.POP.TOTL.FE.ZS  55.289281  55.132533  54.971634
# 96   Hong Kong SAR, China  SP.POP.TOTL.FE.ZS  48.457156  48.485778  48.551298
# 145                Latvia  SP.POP.TOTL.FE.ZS  55.906252  55.733535  55.544812
# ..                    ...                ...        ...        ...        ...
# 182                  Oman  SP.POP.TOTL.FE.ZS  49.820614  49.861010  49.895089
# 22                Bahrain  SP.POP.TOTL.FE.ZS  44.320466  44.289992  44.256716
# 8    United Arab Emirates  SP.POP.TOTL.FE.ZS  39.234482  38.912217  38.652042
# 200                 Qatar  SP.POP.TOTL.FE.ZS  49.042188  48.201242  47.213173
# 110        Not classified  SP.POP.TOTL.FE.ZS        NaN        NaN        NaN
#
# ...

# %% [markdown]
# ## Top 20  Countries With Highest Population For 2022

# %%
top_ten_countries = total_population_sort.head(10)
print('Top Ten Countries Of Total Population')
print(top_ten_countries)
# Out:
# Top Ten Countries Of Total Population
#               Country Name     Indicator Code       1960       1961  \
# 10                 Armenia  SP.POP.TOTL.FE.ZS  51.441327  51.396935
# 248                Ukraine  SP.POP.TOTL.FE.ZS  55.483038  55.382402
# 25                 Belarus  SP.POP.TOTL.FE.ZS  55.289281  55.132533
# 96    Hong Kong SAR, China  SP.POP.TOTL.FE.ZS  48.457156  48.485778
# 145                 Latvia  SP.POP.TOTL.FE.ZS  55.906252  55.733535
# 202     Russian Federation  SP.POP.TOTL.FE.ZS  55.198921  55.075532
# 256  Virgin Islands (U.S.)  SP.POP.TOTL.FE.ZS  49.624175  48.948511
# 146       Macao SAR, China  SP.POP.TOTL.FE.ZS  50.198854  50.181338
# 143              Lithuania  SP.POP.TOTL.FE.ZS  53.671579  53.586503
# 82                 Georgia  SP.POP.TOTL.FE.ZS  52.620097  52.588808
#
#           1962       1963       1964       1965       1966       1967  ...  \
# 10   51.358769  51.323557  51.292590  51.269644  51.251233  51.236016  ...
# ...

# %%
#Data Visuaization
def add_value_labels(ax,spacing=20):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
    
    va='bottom' if y>=0 else 'top'
    label= '()'.format(y)
    y_shift = spacing * (1 if y >=0 else -1),
    ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# ## Top Ten Countries Of Total Population In Year 2022 & 2000

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"
             
plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population (2022)")
plt.xlabel("Total Population")
plt.ylabel("County")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population in 2000")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Top Ten Countries Of Total Population in Year 1999 & 1989

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"
             
plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population (199)")
plt.xlabel("Total Population")
plt.ylabel("County")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population in 1989")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Top Ten Countries Of Total Population in Year 1988 & 1970

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"
             
plt.subplot(2,2,1)
plot=sns.barplot(x='1988',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population (1988)")
plt.xlabel("Total Population")
plt.ylabel("County")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1970',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population in 1970")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Top Ten Countries of Total Population in Year 1970 & 1960

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"
             
plt.subplot(2,2,1)
plot=sns.barplot(x='1970',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population (1970)")
plt.xlabel("Total Population")
plt.ylabel("County")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten Countries Of Total Population in 1960")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Get Bottom Ten Countries With the Highest Population

# %%
total_population_sort_bt = total_population.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#              Country Name     Indicator Code       1960       1961       1962  \
# 200                 Qatar  SP.POP.TOTL.FE.ZS  49.042188  48.201242  47.213173
# 8    United Arab Emirates  SP.POP.TOTL.FE.ZS  39.234482  38.912217  38.652042
# 22                Bahrain  SP.POP.TOTL.FE.ZS  44.320466  44.289992  44.256716
# 182                  Oman  SP.POP.TOTL.FE.ZS  49.820614  49.861010  49.895089
# 127                Kuwait  SP.POP.TOTL.FE.ZS  40.865380  40.723645  40.688807
# ..                    ...                ...        ...        ...        ...
# 96   Hong Kong SAR, China  SP.POP.TOTL.FE.ZS  48.457156  48.485778  48.551298
# 25                Belarus  SP.POP.TOTL.FE.ZS  55.289281  55.132533  54.971634
# 248               Ukraine  SP.POP.TOTL.FE.ZS  55.483038  55.382402  55.288117
# 10                Armenia  SP.POP.TOTL.FE.ZS  51.441327  51.396935  51.358769
# 110        Not classified  SP.POP.TOTL.FE.ZS        NaN        NaN        NaN
#
# ...

# %%
top_ten_bt_countries = total_population_sort_bt.head(10 )
print("Top Ten Bottom Countries Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Countries Of Total Population:-
#                   Country Name     Indicator Code       1960       1961  \
# 200                      Qatar  SP.POP.TOTL.FE.ZS  49.042188  48.201242
# 8         United Arab Emirates  SP.POP.TOTL.FE.ZS  39.234482  38.912217
# 22                     Bahrain  SP.POP.TOTL.FE.ZS  44.320466  44.289992
# 182                       Oman  SP.POP.TOTL.FE.ZS  49.820614  49.861010
# 127                     Kuwait  SP.POP.TOTL.FE.ZS  40.865380  40.723645
# 205               Saudi Arabia  SP.POP.TOTL.FE.ZS  49.282342  49.255025
# 152                   Maldives  SP.POP.TOTL.FE.ZS  45.340971  45.522182
# 164   Northern Mariana Islands  SP.POP.TOTL.FE.ZS  49.873592  49.927496
# 225  Sint Maarten (Dutch part)  SP.POP.TOTL.FE.ZS  52.418745  51.869806
# 32                      Bhutan  SP.POP.TOTL.FE.ZS  48.323737  48.288861
#
#           1962       1963       1964       1965       1966       1967  ...  \
# ...

# %% [markdown]
# ### Bottom ten countries of total population in year 2022 & 2000

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total Population (2022)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total  Population in 2000")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Bottom Ten Countries Of Total Population in Year 1999 & 1989

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total Population (1999)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total  Population in 1989")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Bottom Ten Countries Of Total Population in Year 1988 & 1970

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1988',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total Population (1988)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1970',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total  Population in 1970")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# ### Bottom Ten Countries of Total Population in Year 1970 & 1960

# %%
#create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1970',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total Population (1970)")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom Countries Of Total  Population in 1960")
plt.xlabel("Total Population")
plt.ylabel("Country")
add_value_labels(plot)

plt.tight_layout()

# %%
population.sample()
# Out:
#    Country Name     Indicator Code       1960      1961       1962       1963  \
# 53       Cyprus  SP.POP.TOTL.FE.ZS  50.765803  50.74928  50.723929  50.701564
#
#          1964       1965       1966       1967  ...       2013       2014  \
# 53  50.688509  50.670533  50.633989  50.589379  ...  49.884744  49.888572
#
#          2015      2016       2017       2018     2019       2020       2021  \
# 53  49.890674  49.89544  49.903312  49.903637  49.9008  49.905983  49.914804
#
#          2022
# 53  49.917618
#
# [1 rows x 65 columns]

# %% [markdown]
# ### Extracted Top Ten Countries with Highest Male Population.

# %%
population.sample(10)
# Out:
#                                     Country Name     Indicator Code  \
# 169                                     Malaysia  SP.POP.TOTL.FE.ZS
# 243                                      Tunisia  SP.POP.TOTL.FE.ZS
# 182                                         Oman  SP.POP.TOTL.FE.ZS
# 61   East Asia & Pacific (excluding high income)  SP.POP.TOTL.FE.ZS
# 17                                       Belgium  SP.POP.TOTL.FE.ZS
# 74      Fragile and conflict affected situations  SP.POP.TOTL.FE.ZS
# 250                                      Uruguay  SP.POP.TOTL.FE.ZS
# 144                                   Luxembourg  SP.POP.TOTL.FE.ZS
# 28                                       Bolivia  SP.POP.TOTL.FE.ZS
# 265                                     Zimbabwe  SP.POP.TOTL.FE.ZS
#
#           1960       1961       1962       1963       1964       1965  \
# 169  48.957145  48.986075  49.011138  49.032747  49.052612  49.071864
# 243  49.737109  49.682536  49.632486  49.582845  49.538264  49.502477
# ...

# %%
total_population_male=population[population['Indicator Code']=='SP.POP.TOTL.MA.IN']
total_population_male
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 65 columns]

# %%
total_population_sort_ma = total_population_male.sort_values(by='2022',ascending=False)
total_population_sort_ma
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 65 columns]

# %%
#get  top ten countries with highest population for 2022
top_ten_male_countries = total_population_sort_ma.head(10)
print("Top Ten Male Countries Of Total Population:-")
print(top_ten_male_countries)
# Out:
# Top Ten Male Countries Of Total Population:-
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []
#
# [0 rows x 65 columns]
